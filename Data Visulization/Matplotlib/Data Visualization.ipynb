# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=[1,3,5,7,9,8]
ypoints=[7,4,5,7,8,5]
plt.plot(xpoints,ypoints,marker='*',linestyle='-',color='red',lw='2')
plt.show()

# %%
import pandas as pd
ds=pd.read_csv("C:/Users/floyd/data/tips.csv")

# %%
ds['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %%
ds.shape
# Out:
# (244, 7)

# %%
ds.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ds.sample(20)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 159       16.49  2.00    Male     No   Sun  Dinner     4
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 59        48.27  6.73    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 60        20.29  3.21    Male    Yes   Sat  Dinner     2
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 127       14.52  2.00  Female     No  Thur   Lunch     2
# 191       19.81  4.19  Female    Yes  Thur   Lunch     2
# 120       11.69  2.31    Male     No  Thur   Lunch     2
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2
# 110       14.00  3.00    Male     No   Sat  Dinner     2
# 123       15.95  2.00    Male     No  Thur   Lunch     2
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 158       13.39  2.61  Female     No   Sun  Dinner     2
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# ...

# %%
ds.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
plt.plot(ds['sex'],ds['smoker'],marker='*',linestyle='dashed',color='red',lw=2,label='line')
plt.title('LinePlot')
plt.xlabel('Gender')
plt.ylabel('smoker')
plt.legend()
plt.show()
